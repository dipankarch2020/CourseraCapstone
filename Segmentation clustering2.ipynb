# %% [markdown]
# # Project : Toronto neighbourhood
#
# ## Step 1 : Collecting Data

# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen

import 

url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
html=urlopen(url)
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ## Step 2 : Structuring and refining Data

# %%
rows=soup.find_all('tr')
print()

df=pd.DataFrame()
data=[]
for row in rows:
    row_str=str(row.text)
    lst=row_str.split("\n")
    #print(lst)
    #print(lst[1])
    row_list=[]
    for x in lst:
        if x !='':
            row_list.append(x)
    data.append(row_list)
    #print(row_list)
#print(data)
df=pd.DataFrame(data)
#print(df)
df_refined=pd.DataFrame([])
df_refined=df[:180]

#df_refined.replace(to_replace="Not Assigned", value="NA",inplace=True)
#df_refined.replace(to_replace="None", value="NA",inplace=True)
df_refined.dropna(axis=1,inplace=True,how='all')
df_refined.dropna(axis=0,inplace=True)

header=df_refined.iloc[0]
df_refined=df_refined[1:]
df_refined.columns=header
#df_refined
#type(df_refined)
df_refined.reset_index(drop=True,inplace=True)
df_refined
# Out:
# <ipython-input-2-49bf22a79caa>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_refined.dropna(axis=1,inplace=True,how='all')
# <ipython-input-2-49bf22a79caa>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_refined.dropna(axis=0,inplace=True)
# 0   Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# ...

# %%
df_refined.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Step 3 : Adding longitude and latitude

# %%
long_lat_all=pd.read_csv("Geospatial_Coordinates.csv")
postal_codes=df_refined["Postal Code"]
#print(long_lat_all["Postal Code"][0])

long_lat_list=[]
long_lat=pd.DataFrame([['0','0']])
for p_code in postal_codes:
        for n in range(0,103):
            if p_code == long_lat_all["Postal Code"][n]:
                #print(p_code,long_lat_all["Postal Code"][n])
                #lnlat=pd.DataFrame([long_lat_all["Latitude"][n],long_lat_all["Longitude"][n]])
                lst=[float(long_lat_all["Latitude"][n]),float(long_lat_all["Longitude"][n])]
                long_lat_list=long_lat_list+[lst]
                #lnlat=lnlat.transpose()
                #long_lat.append(lnlat)
                #print(long_lat_all["Latitude"][n],long_lat_all["Longitude"][n])
#print(long_lat_list)
long_lat=pd.DataFrame(long_lat_list)


long_lat.columns=['Latitude','Longitude']
print(long_lat)

df_final=pd.concat([df_refined,long_lat],axis=1)
df_final[:20]
# Out:
#       Latitude  Longitude
# 0    43.753259 -79.329656
# 1    43.725882 -79.315572
# 2    43.654260 -79.360636
# 3    43.718518 -79.464763
# 4    43.662301 -79.389494
# ..         ...        ...
# 98   43.653654 -79.506944
# 99   43.665860 -79.383160
# 100  43.662744 -79.321558
# 101  43.636258 -79.498509
# 102  43.628841 -79.520999
#
# [103 rows x 2 columns]
#    Postal Code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# ...

# %%
import geopy.geocoders
from geopy.geocoders import Nominatim
#from nominatim import Nominatim
address = 'Toronto,Ontario'

geolocator = Nominatim(user_agent="tto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.6534817, -79.3839347.

# %% [markdown]
# ## Creating map of Toronto

# %%
import folium

Toronto_map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_final['Latitude'], df_final['Longitude'], df_final['Borough'], df_final['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Toronto_map)  
    

display(Toronto_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'RU3YHO4OWI4WIPJUB5L02UTAB3ZY1HFRZOT2CH5YAQLLHOXQ' # your Foursquare ID
CLIENT_SECRET = '4E2S4A24DW2QDBOBG2T52R2D2NJFDOLBCD1VQKKE4BSTVNAC' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RU3YHO4OWI4WIPJUB5L02UTAB3ZY1HFRZOT2CH5YAQLLHOXQ
# CLIENT_SECRET:4E2S4A24DW2QDBOBG2T52R2D2NJFDOLBCD1VQKKE4BSTVNAC

# %%
Toronto_data=df_final
Toronto_data.loc[0, 'Neighborhood']

neighborhood_latitude = Toronto_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = Toronto_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = Toronto_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Parkwoods are 43.7532586, -79.3296565.

# %%
LIMIT=50
radius=500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=RU3YHO4OWI4WIPJUB5L02UTAB3ZY1HFRZOT2CH5YAQLLHOXQ&client_secret=4E2S4A24DW2QDBOBG2T52R2D2NJFDOLBCD1VQKKE4BSTVNAC&v=20180605&ll=43.7532586,-79.3296565&radius=500&limit=50'

# %%
import requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ecf8d29b9a389001b60aaa8'},
#  'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."},
#   'headerLocation': 'Parkwoods - Donalda',
#   'headerFullLocation': 'Parkwoods - Donalda, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 2,
#   'suggestedBounds': {'ne': {'lat': 43.757758604500005,
#     'lng': -79.32343823984928},
#    'sw': {'lat': 43.7487585955, 'lng': -79.33587476015072}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8d9dcdd5fbbbb6b3003c7b',
#        'name': 'Brookbanks Park',
#        'location': {'address': 'Toronto',
#         'lat': 43.751976046055574,
# ...

# %%
from pandas.io.json import json_normalize
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) 

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]
# Out:
# <ipython-input-13-01cd187bd7e9>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues) # flatten JSON

# %%
nearby_venues
# Out:
#         venue.name                                   venue.categories  \
# 0  Brookbanks Park  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 1    Variety Store  [{'id': '4bf58dd8d48988d1f9941735', 'name': 'F...
#
#    venue.location.lat  venue.location.lng
# 0           43.751976          -79.332140
# 1           43.751974          -79.333114

# %%
venue_list=[]
for bro in Toronto_data['Borough']:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
    results = requests.get(url).json()
    venues = results['response']['groups'][0]['items']
    nearby_venues = json_normalize(venues) 
    filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
    nearby_venues =nearby_venues.loc[:, filtered_columns]
    venue_list.append(nearby_venues)
    
df_venues=pd.DataFrame(venue_list)
df_venues
# Out:
# <ipython-input-19-3c9881fa2fec>:13: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues)
#                                                      0
# 0            venue.name                            ...
# 1            venue.name                            ...
# 2            venue.name                            ...
# 3            venue.name                            ...
# 4            venue.name                            ...
# ..                                                 ...
# 98           venue.name                            ...
# 99           venue.name                            ...
# 100          venue.name                            ...
# 101          venue.name                            ...
# 102          venue.name                            ...
#
# [103 rows x 1 columns]
